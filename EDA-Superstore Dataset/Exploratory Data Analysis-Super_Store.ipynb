# %%
from IPython.display import Image
Image(filename='sparks.jpg')

# %% [markdown]
# # Author : Bhoi Arpan Ashutosh

# %% [markdown]
# # Exploratory Data Analysis - Super Store

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(14,7)

# %%
data=pd.read_csv('SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# Now , we Will Check That There are Null Values In Dataset Or not.

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.rename(columns = {'Ship Mode':'Ship_Mode'}, inplace = True)

# %%
data.rename(columns = {'Sub-Category':'SubCategory'}, inplace = True)

# %%
data
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.rename(columns = {'Postal Code':'Postal_code'}, inplace = True)

# %%
data
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.Ship_Mode.value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship_Mode, dtype: int64

# %%
plt.xticks(rotation=60)
sns.barplot(x=data.Ship_Mode.value_counts().index,y=data.Ship_Mode.value_counts(),data=data)

# %%
sns.pairplot(data,hue='Category')

# %%
data.Category.value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.title('Segment')
plt.pie(data['Segment'].value_counts(), labels=data['Segment'].value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20be4d5d730>,
# ...
#  [Text(-0.06704018356682018, 1.0979551966211223, 'Consumer'),
#   Text(-0.5268843289816147, -0.9656049419268699, 'Corporate'),
#   Text(0.9316986195588344, -0.5847543777622897, 'Home Office')],
#  [Text(-0.03656737285462918, 0.5988846527024302, '51.9%'),
#   Text(-0.28739145217178985, -0.5266936046873835, '30.2%'),
#   Text(0.5081992470320914, -0.31895693332488523, '17.8%')])

# %% [markdown]
# # Profit By Segment

# %%
plt.xticks(rotation=60)
sns.barplot(x='Segment',y='Profit',data=data)

# %% [markdown]
# # Sales by Segment

# %%
plt.xticks(rotation=60)
sns.barplot(x='Segment',y='Sales',data=data)

# %%
plt.xticks(rotation=60)
sns.barplot(x='Category',y='Sales',data=data,palette='magma')

# %%
data.SubCategory.value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: SubCategory, dtype: int64

# %% [markdown]
# # Profit By Sub-Categories

# %%
plt.xticks(rotation=60)
sns.barplot(x='SubCategory',y='Sales',data=data,palette='rocket')

# %%
data.State.value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# # Which Category Has Maximum Profit in California?

# %%
sta=data[['Segment','Profit','Category']]
sta_df=data.State=='California'

# %%
new_df=sta[sta_df]
cali_df=new_df.sort_values(by=['Profit'],ascending=False)
cali_df
# Out:
#           Segment     Profit         Category
# 8858    Corporate  1906.4850  Office Supplies
# 3273  Home Office  1049.9850       Technology
# 4619  Home Office  1007.9832       Technology
# 3983     Consumer   944.9865       Technology
# 9929     Consumer   944.9865       Technology
# ...           ...        ...              ...
# 1505  Home Office  -175.8708        Furniture
# 3480    Corporate  -195.4788        Furniture
# 557      Consumer  -217.0480        Furniture
# 2539    Corporate  -219.1644        Furniture
# 3770     Consumer  -325.5720        Furniture
#
# [2001 rows x 3 columns]

# %%
cali_df.Category.value_counts()
# Out:
# Office Supplies    1198
# Furniture           444
# Technology          359
# Name: Category, dtype: int64

# %%
sns.barplot(x=cali_df.Category.value_counts().index,y=cali_df.Category.value_counts(),data=cali_df,palette='Blues_d')

# %% [markdown]
# # Which SubCategory Has Maximum Profit in California?

# %%
sub=data[['Segment','Profit','SubCategory']]
sub_df=data.State=='California'

# %%
sc=sub[sub_df]
calis_df=sc.sort_values(by=['Segment'],ascending=False)
calis_df
# Out:
#           Segment   Profit  SubCategory
# 6514  Home Office  23.2182       Phones
# 7853  Home Office   4.8804        Paper
# 1503  Home Office   3.0814  Furnishings
# 1502  Home Office   3.3520       Phones
# 1498  Home Office   6.5830      Binders
# ...           ...      ...          ...
# 4452     Consumer  20.6612    Envelopes
# 4451     Consumer   8.6360  Furnishings
# 4450     Consumer  87.7443    Envelopes
# 4449     Consumer   3.1104        Paper
# 9993     Consumer  72.9480   Appliances
#
# [2001 rows x 3 columns]

# %%
calis_df.SubCategory.value_counts()
# Out:
# Paper          289
# Binders        276
# Furnishings    191
# Phones         172
# Art            165
# Storage        160
# Accessories    147
# Chairs         130
# Appliances      94
# Labels          83
# Tables          71
# Bookcases       52
# Envelopes       46
# Supplies        43
# Fasteners       42
# Machines        23
# Copiers         17
# Name: SubCategory, dtype: int64

# %%
plt.xticks(rotation=80)
sns.barplot(x=calis_df.SubCategory.value_counts().index,y=calis_df.SubCategory.value_counts(),data=calis_df,palette='Blues_d')

# %% [markdown]
# # Which Region Has Maximum Profit?

# %%
sns.barplot(x='Region',y='Profit',data=data)

# %% [markdown]
# # How Much  Profit has West Region by Category ?

# %%
west=data[['Category','Profit','Segment']]
west_df=data.Region=='West'

# %%
reg=west[west_df]
reg_df=reg.sort_values(by=['Profit'],ascending=False)
reg_df
# Out:
#              Category     Profit      Segment
# 8153       Technology  6719.9808     Consumer
# 8858  Office Supplies  1906.4850    Corporate
# 7818  Office Supplies  1644.2913  Home Office
# 1644       Technology  1480.4671    Corporate
# 515        Technology  1379.9770  Home Office
# ...               ...        ...          ...
# 9231  Office Supplies  -694.2936     Consumer
# 1369        Furniture  -786.7440     Consumer
# 463         Furniture  -814.4832  Home Office
# 7641       Technology  -938.2800  Home Office
# 3011       Technology -3399.9800  Home Office
#
# [3203 rows x 3 columns]

# %%
sns.barplot(x=reg_df.Category,y=reg_df.Profit)

# %% [markdown]
# # Popular Category in West Region...

# %%
reg_df.Category.value_counts()
# Out:
# Office Supplies    1897
# Furniture           707
# Technology          599
# Name: Category, dtype: int64

# %%
data
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Which Sub-Category Has Maximum Sales in West Region?

# %%
sub=data[['SubCategory','Profit','Segment']]
sub_df=data.Region=='West'

# %%
cat=sub[sub_df]
cat_df=cat.sort_values(by=['Profit','SubCategory'],ascending=[False,False])
cat_df
# Out:
#      SubCategory     Profit      Segment
# 8153     Copiers  6719.9808     Consumer
# 8858     Binders  1906.4850    Corporate
# 7818     Binders  1644.2913  Home Office
# 1644     Copiers  1480.4671    Corporate
# 515      Copiers  1379.9770  Home Office
# ...          ...        ...          ...
# 9231     Binders  -694.2936     Consumer
# 1369   Bookcases  -786.7440     Consumer
# 463       Tables  -814.4832  Home Office
# 7641    Machines  -938.2800  Home Office
# 3011    Machines -3399.9800  Home Office
#
# [3203 rows x 3 columns]

# %%
cat_df.SubCategory.value_counts()
# Out:
# Binders        471
# Paper          450
# Furnishings    304
# Phones         277
# Storage        266
# Accessories    258
# Art            250
# Chairs         207
# Appliances     136
# Labels         116
# Tables         116
# Bookcases       80
# Fasteners       72
# Supplies        69
# Envelopes       67
# Machines        39
# Copiers         25
# Name: SubCategory, dtype: int64

# %%
plt.xticks(rotation=60)
sns.barplot(x=cat_df.SubCategory,y=cat_df.Profit)

# %% [markdown]
# # Analysis on Ship_Mode

# %%
data.Ship_Mode.value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship_Mode, dtype: int64

# %% [markdown]
# Standard Class is the most popular ship_Mode

# %% [markdown]
# # Which state Has Maximum Sales by Standard Class?

# %%
mode=data[['State','Sales']]
mode_df=data.Ship_Mode=='Standard Class'

# %%
cname=mode[mode_df]
cname_df=cname.sort_values(by=['Sales'],ascending=False).head(10)
cname_df
# Out:
#              State      Sales
# 2697       Florida  22638.480
# 6826       Indiana  17499.950
# 4190      Delaware  10499.970
# 9039      Michigan   9892.740
# 4098     Minnesota   9449.950
# 4277    New Jersey   9099.930
# 6425  Pennsylvania   8399.976
# 165          Texas   8159.952
# 6626      New York   6999.960
# 509        Georgia   6354.950

# %%
plt.xticks(rotation=60)
sns.barplot(x='State',y='Sales',data=cname_df)

# %% [markdown]
# # Which Category Has Maximum Sales by Standard Class?

# %%
sc=data[['Category','Sales']]
sc_df=data.Ship_Mode=='Standard Class'

# %%
cla=sc[sc_df]
cla_df=cla.sort_values(by=['Sales'],ascending=False)
cla_df
# Out:
#              Category      Sales
# 2697       Technology  22638.480
# 6826       Technology  17499.950
# 4190       Technology  10499.970
# 9039  Office Supplies   9892.740
# 4098  Office Supplies   9449.950
# ...               ...        ...
# 976   Office Supplies      1.080
# 8024  Office Supplies      1.044
# 7548  Office Supplies      0.898
# 8658  Office Supplies      0.836
# 4101  Office Supplies      0.444
#
# [5968 rows x 2 columns]

# %% [markdown]
# # Which Region Has Maximum Sales by Standard Class?

# %%
sal=data[['Region','Sales','SubCategory','State']]
sal_df=data.Ship_Mode=='Standard Class'

# %%
region=sal[sal_df]
region_df=region.sort_values(by=['Sales'],ascending=False).head(30)
region_df
# Out:
#        Region      Sales  SubCategory         State
# 2697    South  22638.480     Machines       Florida
# 6826  Central  17499.950      Copiers       Indiana
# 4190     East  10499.970      Copiers      Delaware
# 9039  Central   9892.740      Binders      Michigan
# 4098  Central   9449.950      Binders     Minnesota
# 4277     East   9099.930     Machines    New Jersey
# 6425     East   8399.976      Copiers  Pennsylvania
# 165   Central   8159.952     Machines         Texas
# 6626     East   6999.960     Machines      New York
# 509     South   6354.950      Binders       Georgia
# 7666     East   5399.910      Copiers  Rhode Island
# 6340     East   5199.960     Machines      New York
# 8858     West   5083.960      Binders    California
# 8990  Central   4899.930      Copiers      Missouri
# 1085     East   4899.930     Machines      New York
# 2492     East   4548.810       Phones      New York
# 7772     East   4499.985     Machines          Ohio
# ...

# %%
plt.xticks(rotation=60)
sns.barplot(x='State',y='Sales',hue='Region',data=region_df)

# %%
data
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Which Region has Maximum sales of Phones Subcategory?

# %%
sub=data[['Region','Sales','State','Ship_Mode']]
sub_df=data.SubCategory=='Phones'

# %%
ph=sub[sub_df]
ph_df=ph.sort_values(by=['Sales'],ascending=False).head(10)
ph_df
# Out:
#        Region     Sales       State       Ship_Mode
# 2492     East  4548.810    New York  Standard Class
# 4297    South  4367.896     Florida    Second Class
# 6014     West  4158.912  California     First Class
# 7583    South  3499.930    Virginia  Standard Class
# 9660     West  3023.928  California  Standard Class
# 8312    South  2939.930     Georgia  Standard Class
# 487   Central  2735.952    Illinois     First Class
# 1805     West  2575.944  California     First Class
# 5530  Central  2479.960    Nebraska  Standard Class
# 2624     East  2399.600    New York     First Class

# %%
plt.title('Sales By States For Phones')
plt.pie(ph_df.Sales,labels=ph_df.State,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20be62a19d0>,
# ...
#  [Text(0.9968110332223553, 0.4651534843964738, 'New York'),
#   Text(0.30223723447578704, 1.0576637717613422, 'Florida'),
#   Text(-0.565628647475938, 0.9434321560952548, 'California'),
#   Text(-1.0522912048788795, 0.32044222589190163, 'Virginia'),
#   Text(-1.040439797539828, -0.357050455391506, 'California'),
#   Text(-0.6811776213237426, -0.8637112064849732, 'Georgia'),
#   Text(-0.1349638759753103, -1.091688944792298, 'Illinois'),
#   Text(0.4149954251802831, -1.0187142862841554, 'California'),
#   Text(0.8422664205600383, -0.7075219267252294, 'Nebraska'),
#   Text(1.070952814706019, -0.2511176391121409, 'New York')],
#  [Text(0.5437151090303756, 0.2537200823980766, '13.9%'),
#   Text(0.16485667335042928, 0.5769075118698229, '13.3%'),
#   Text(-0.30852471680505705, 0.5145993578701389, '12.7%'),
#   Text(-0.573977020843025, 0.17478666866830997, '10.7%'),
#   Text(-0.5675126168399062, -0.19475479384991232, '9.2%'),
# ...

# %%
ship=data[['SubCategory','Sales']]
ship_df=data.Ship_Mode=='Same Day'

# %%
mode=ship[ship_df]
mode_df=mode.sort_values(by=['Sales'],ascending=False)
mode_df
# Out:
#      SubCategory     Sales
# 683     Machines  7999.980
# 8204    Machines  4643.800
# 5126    Machines  2799.960
# 9929     Copiers  2799.960
# 1438      Chairs  2453.430
# ...          ...       ...
# 9224     Binders     1.408
# 987      Binders     1.112
# 2106     Binders     0.876
# 4711     Binders     0.852
# 9292     Binders     0.556
#
# [543 rows x 2 columns]

# %%
plt.xticks(rotation=60)
sns.barplot(x='SubCategory',y='Sales',palette='viridis',data=mode_df)

# %%
first=data[['SubCategory','Sales','Region']]
first_df=data.Ship_Mode=='First Class'

# %%
sal=first[first_df]
sal_df=sal.sort_values(by=['Sales'],ascending=False).head(10)
sal_df
# Out:
#      SubCategory      Sales   Region
# 8153     Copiers  13999.960     West
# 2623     Copiers  11199.968     East
# 4218    Machines   4799.984     West
# 353      Binders   4355.168     East
# 6014      Phones   4158.912     West
# 7683     Binders   3812.970  Central
# 8100    Machines   3357.600     West
# 1644     Copiers   3149.930     West
# 977     Machines   3059.982  Central
# 8749     Binders   3050.376     East

# %%
plt.xticks(rotation=70)
sns.barplot(x='SubCategory',y='Sales',data=sal_df)

# %%
sec=data[['SubCategory','Sales','Region']]
sec_df=data.Ship_Mode=='Second Class'

# %%
se=sec[sec_df]
se_df=se.sort_values(by=['Sales'],ascending=False)
se_df
# Out:
#      SubCategory     Sales   Region
# 8488    Machines  8749.950    South
# 2505    Supplies  8187.650     West
# 6520     Binders  5443.960  Central
# 5884    Supplies  4912.590     West
# 1803    Supplies  4663.736     East
# ...          ...       ...      ...
# 8722     Binders     1.524  Central
# 9304     Binders     1.476  Central
# 7117     Binders     1.344     West
# 9382         Art     1.344    South
# 6089     Binders     1.188     West
#
# [1945 rows x 3 columns]

# %%
plt.xticks(rotation=70)
sns.barplot(x='SubCategory',y='Sales',data=se_df)
