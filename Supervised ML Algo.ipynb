# %% [markdown]
# # THE SPARKS FOUNDATION

# %%
from IPython.display import Image
Image(filename='sparks-Copy1.jpg')

# %% [markdown]
# # Internship On Data Science & Business Analytics

# %% [markdown]
# # TASK 2 : Prediction Using Supervised Machine-Learning Algorithm

# %% [markdown]
# # Name : Bhoi Arpan Ashutosh

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(13,7)
sns.set_style('darkgrid')

# %%
data=pd.read_csv('http://bit.ly/w-data')

# %%
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
sns.distplot(data['Hours'],bins=9)

# %%
sns.distplot(data['Scores'],bins=9,color='purple')

# %%
plt.title('HOURS_VS_SCORES',color='green')
sns.scatterplot(x=data.Hours,y=data.Scores,color='r', marker='o',s=130)

# %% [markdown]
# # Training Model

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['Hours']],data.Scores)
# Out:
# LinearRegression()

# %%
plt.title('HOURS_VS_SCORES',color='blue')
plt.xlabel('HOURS')
plt.ylabel('SCORES')
sns.scatterplot(data.Hours,data.Scores, color='r', marker='o',s=150)
plt.plot(data.Hours, reg.predict(data[['Hours']]), color='green')
plt.legend(['Regression_Line','DataPoints'])

# %%
prediction = reg.predict(data[['Hours']])
prediction
# Out:
# array([26.92318188, 52.3402707 , 33.76624426, 85.57800223, 36.69898527,
#        17.14737849, 92.4210646 , 56.25059205, 83.62284155, 28.87834256,
#        77.75735951, 60.16091341, 46.47478866, 34.74382459, 13.23705714,
#        89.48832358, 26.92318188, 21.05769985, 62.11607409, 74.8246185 ,
#        28.87834256, 49.40752968, 39.63172629, 69.9367168 , 78.73493985])

# %%
data['PredictedScores'] = prediction
data
# Out:
#     Hours  Scores  PredictedScores
# 0     2.5      21        26.923182
# 1     5.1      47        52.340271
# 2     3.2      27        33.766244
# 3     8.5      75        85.578002
# 4     3.5      30        36.698985
# 5     1.5      20        17.147378
# 6     9.2      88        92.421065
# 7     5.5      60        56.250592
# 8     8.3      81        83.622842
# 9     2.7      25        28.878343
# 10    7.7      85        77.757360
# 11    5.9      62        60.160913
# 12    4.5      41        46.474789
# 13    3.3      42        34.743825
# 14    1.1      17        13.237057
# 15    8.9      95        89.488324
# 16    2.5      30        26.923182
# 17    1.9      24        21.057700
# 18    6.1      67        62.116074
# 19    7.4      69        74.824618
# 20    2.7      30        28.878343
# 21    4.8      54        49.407530
# 22    3.8      35        39.631726
# 23    6.9      76        69.936717
# 24    7.8      86        78.734940

# %% [markdown]
# # Q : What Will be predicted Score if a student studies for 9.25hrs/day?

# %%
print("Predicted Score= {}".format(reg.predict([[9.25]])))
# Out:
# Predicted Score= [92.90985477]

# %% [markdown]
# # How Can We Predict Above Value?

# %% [markdown]
# y=mx+c
#
# where :
#
#     y= Dependent Var
#     x= independent or input variable
#     m=coefficient of x
#     c= intercept value

# %% [markdown]
# here , x=9.25
#
# so now i have to find out the value of m & c

# %%
# value of m
reg.coef_
# Out:
# array([9.77580339])

# %%
# value of c
reg.intercept_
# Out:
# 2.483673405373196

# %%
#so ,final Result 

#x=9.25
#m=9.77580339
#c=2.483673405373196

#y=(mx)+c

#y=9.77580339*9.25 + 2.483673405373196
#y=92.90985477
